# %%
import datetime as dt
from bs4 import BeautifulSoup
import requests
import re
import time
import random
import pandas as pd
import os
import numpy as np

# %%
master_df = pd.read_csv('week_4.csv')

# %%
master_df.head(15)
# Out:
#    Pos             Name  Salary TeamAbbrev  AvgPointsPerGame  \
# 0   WR  DeAndre Hopkins    8500        ARI             26.53
# 1   QB    Lamar Jackson    8100        BAL             20.08
# 2   RB     Alvin Kamara    8000         NO             36.60
# 3   QB   Russell Wilson    7800        SEA             36.33
# 4   RB  Ezekiel Elliott    7800        DAL             22.90
# 5   WR   Michael Thomas    7600         NO              4.70
# 6   RB      Dalvin Cook    7600        MIN             22.93
# 7   RB    Derrick Henry    7400        TEN             19.17
# 8   QB       Josh Allen    7300        BUF             35.64
# 9   QB     Dak Prescott    7200        DAL             31.64
# 10  RB    Austin Ekeler    7100        LAC             19.93
# 11  QB     Kyler Murray    7000        ARI             28.38
# 12  WR    Tyler Lockett    7000        SEA             25.63
# 13  RB       Nick Chubb    7000        CLE             20.97
# 14  RB     James Conner    6900        PIT             18.23
#
#     Projected Points  dk_pos_sal_avg_points
# 0               20.1              19.347368
# 1               24.0              24.040000
# 2               22.9              19.637500
# 3               23.0               9.320000
# 4               20.6              20.421053
# 5               14.1              15.870909
# 6               18.9              17.600000
# 7               15.2              19.917391
# 8               22.5              19.996000
# 9               23.0              18.897500
# 10              16.5              16.438462
# 11              21.9              20.670000
# 12              17.6              15.404651
# 13              13.8              14.676923
# 14              15.4              15.310526

# %%
master_df['val_above_sal'] = master_df['Projected Points'] - master_df['dk_pos_sal_avg_points']

# %%
master_df['Points Per Dollar'] = master_df['Projected Points'] / \
    master_df['Salary']
master_df['Points Per 1K'] = master_df['Projected Points'] / 1000
master_df['Value'] = master_df['Projected Points'] / \
    (master_df['Salary']/1000)

# %%
master_df
# Out:
#      Pos             Name  Salary TeamAbbrev  AvgPointsPerGame  \
# 0     WR  DeAndre Hopkins    8500        ARI             26.53
# 1     QB    Lamar Jackson    8100        BAL             20.08
# 2     RB     Alvin Kamara    8000         NO             36.60
# 3     QB   Russell Wilson    7800        SEA             36.33
# 4     RB  Ezekiel Elliott    7800        DAL             22.90
# ..   ...              ...     ...        ...               ...
# 421   TE      Deon Yelder    2500         KC              0.00
# 422  DST          Texans     2500        HOU              1.67
# 423  DST          Browns     2300        CLE              6.00
# 424  DST           Lions     2200        DET              1.67
# 425  DST        Dolphins     2000        MIA              6.00
#
#      Projected Points  dk_pos_sal_avg_points  val_above_sal  \
# 0                20.1              19.347368       0.752632
# 1                24.0              24.040000      -0.040000
# 2                22.9              19.637500       3.262500
# 3                23.0               9.320000      13.680000
# 4                20.6              20.421053       0.178947
# ..                ...                    ...            ...
# 421               0.4               1.870506      -1.470506
# 422               6.1               5.530973       0.569027
# 423               5.8               5.700935       0.099065
# 424               4.7               5.894737      -1.194737
# 425               5.7               4.740741       0.959259
#
#      Points Per Dollar  Points Per 1K     Value
# 0             0.002365         0.0201  2.364706
# 1             0.002963         0.0240  2.962963
# 2             0.002863         0.0229  2.862500
# 3             0.002949         0.0230  2.948718
# 4             0.002641         0.0206  2.641026
# ..                 ...            ...       ...
# 421           0.000160         0.0004  0.160000
# 422           0.002440         0.0061  2.440000
# 423           0.002522         0.0058  2.521739
# 424           0.002136         0.0047  2.136364
# 425           0.002850         0.0057  2.850000
#
# [426 rows x 11 columns]

# %%
good_choices = master_df[(master_df['val_above_sal']>0) & (master_df['Projected Points']>10.68)]

# %%
good_choices.sort_values(by=['Pos','val_above_sal'], ascending=False)
# Out:
#     Pos                   Name  Salary TeamAbbrev  AvgPointsPerGame  \
# 34   WR           Robert Woods    6300        LAR             17.87
# 71   WR         Robby Anderson    5400        CAR             20.27
# 52   WR         Terry McLaurin    5800        WAS             17.40
# 12   WR          Tyler Lockett    7000        SEA             25.63
# 53   WR      Odell Beckham Jr.    5800        CLE             10.83
# 58   WR         DeVante Parker    5700        MIA             12.30
# 59   WR         Julian Edelman    5700         NE             15.37
# 19   WR      Allen Robinson II    6700        CHI             16.63
# 20   WR           Amari Cooper    6700        DAL             18.23
# 98   WR          Curtis Samuel    4800        CAR              8.13
# 120  WR            Golden Tate    4600        NYG              9.15
# 38   WR         Michael Gallup    6200        DAL             14.87
# 92   WR       Marvin Jones Jr.    4900        DET              9.97
# 124  WR       Preston Williams    4500        MIA              6.80
# 47   WR          Will Fuller V    5900        HOU             12.53
# 0    WR        DeAndre Hopkins    8500        ARI             26.53
# 21   WR            Cooper Kupp    6700        LAR             16.90
# 84   WR          Jarvis Landry    5100        CLE              8.77
# 126  WR            Keelan Cole    4500        JAX             13.93
# 40   WR             Tyler Boyd    6100        CIN             17.67
# 127  WR          Brandin Cooks    4500        HOU              7.93
# 63   WR        Diontae Johnson    5600        PIT             11.60
# 72   WR            CeeDee Lamb    5400        DAL             14.33
# 17   WR           Stefon Diggs    6800        BUF             21.27
# 77   WR            T.Y. Hilton    5300        IND              7.77
# 79   WR       Justin Jefferson    5200        MIN             15.17
# 89   WR         Darius Slayton    5000        NYG             14.93
# 83   TE           Mike Gesicki    5100        MIA             14.83
# 117  TE           Hunter Henry    4600        LAC             12.20
# 80   TE          Darren Waller    5200         LV             14.97
# 60   TE           Tyler Higbee    5700        LAR             14.47
# 2    RB           Alvin Kamara    8000         NO             36.60
# 65   RB          David Johnson    5600        HOU             13.17
# 32   RB  Clyde Edwards-Helaire    6400         KC             18.07
# 23   RB        Jonathan Taylor    6600        IND             16.70
# 56   RB             Mike Davis    5700        CAR             12.87
# 67   RB       David Montgomery    5500        CHI             12.50
# 42   RB           Kenyan Drake    6000        ARI             11.63
# 6    RB            Dalvin Cook    7600        MIN             22.93
# 54   RB              Joe Mixon    5800        CIN              9.40
# 114  RB        Ronald Jones II    4700         TB             10.07
# 48   RB       Devin Singletary    5900        BUF             12.00
# 90   RB           Myles Gaskin    5000        MIA             13.10
# 29   RB         James Robinson    6500        JAX             21.63
# 4    RB        Ezekiel Elliott    7800        DAL             22.90
# 14   RB           James Conner    6900        PIT             18.23
# 10   RB          Austin Ekeler    7100        LAC             19.93
# 3    QB         Russell Wilson    7800        SEA             36.33
# 9    QB           Dak Prescott    7200        DAL             31.64
# 8    QB             Josh Allen    7300        BUF             35.64
# 26   QB         Deshaun Watson    6600        HOU             18.53
# 11   QB           Kyler Murray    7000        ARI             28.38
# 49   QB             Drew Brees    5800         NO             18.80
# 73   QB       Ryan Fitzpatrick    5400        MIA             20.32
# 86   QB           Daniel Jones    5100        NYG             13.05
#
#      Projected Points  dk_pos_sal_avg_points  val_above_sal  \
# 34               16.0              12.881270       3.118730
# 71               13.8              10.844776       2.955224
# 52               14.4              12.025373       2.374627
# 12               17.6              15.404651       2.195349
# 53               13.8              12.025373       1.774627
# 58               15.0              13.357143       1.642857
# 59               15.0              13.357143       1.642857
# 19               17.0              15.594340       1.405660
# 20               16.9              15.594340       1.305660
# 98               11.1               9.988889       1.111111
# 120              11.0               9.935849       1.064151
# 38               12.6              11.572075       1.027925
# 92               11.8              10.839583       0.960417
# 124              11.0              10.109134       0.890866
# 47               13.1              12.243077       0.856923
# 0                20.1              19.347368       0.752632
# 21               16.3              15.594340       0.705660
# 84               12.6              11.898507       0.701493
# 126              10.8              10.109134       0.690866
# 40               13.9              13.235088       0.664912
# 127              10.7              10.109134       0.590866
# 63               11.8              11.217391       0.582609
# 72               11.4              10.844776       0.555224
# 17               16.0              15.559149       0.440851
# 77               12.7              12.270411       0.429589
# 79               10.8              10.608732       0.191268
# 89               12.6              12.526437       0.073563
# 83               12.1               9.010000       3.090000
# 117              12.5               9.575000       2.925000
# 80               14.2              12.660000       1.540000
# 60               12.8              11.825000       0.975000
# 2                22.9              19.637500       3.262500
# 65               15.3              12.966047       2.333953
# 32               16.8              14.527586       2.272414
# 23               15.2              12.928571       2.271429
# 56               15.6              13.707500       1.892500
# 67               13.4              11.516071       1.883929
# 42               15.5              13.955319       1.544681
# 6                18.9              17.600000       1.300000
# 54               16.4              15.604444       0.795556
# 114              11.8              11.177528       0.622472
# 48               14.5              14.145000       0.355000
# 90               12.6              12.412368       0.187632
# 29               15.4              15.220690       0.179310
# 4                20.6              20.421053       0.178947
# 14               15.4              15.310526       0.089474
# 10               16.5              16.438462       0.061538
# 3                23.0               9.320000      13.680000
# 9                23.0              18.897500       4.102500
# 8                22.5              19.996000       2.504000
# 26               21.5              19.623182       1.876818
# 11               21.9              20.670000       1.230000
# 49               19.5              18.358788       1.141212
# 73               18.7              17.670980       1.029020
# 86               15.2              14.304688       0.895312
#
#      Points Per Dollar  Points Per 1K     Value
# 34            0.002540         0.0160  2.539683
# 71            0.002556         0.0138  2.555556
# 52            0.002483         0.0144  2.482759
# 12            0.002514         0.0176  2.514286
# 53            0.002379         0.0138  2.379310
# 58            0.002632         0.0150  2.631579
# 59            0.002632         0.0150  2.631579
# 19            0.002537         0.0170  2.537313
# 20            0.002522         0.0169  2.522388
# 98            0.002312         0.0111  2.312500
# 120           0.002391         0.0110  2.391304
# 38            0.002032         0.0126  2.032258
# 92            0.002408         0.0118  2.408163
# 124           0.002444         0.0110  2.444444
# 47            0.002220         0.0131  2.220339
# 0             0.002365         0.0201  2.364706
# 21            0.002433         0.0163  2.432836
# 84            0.002471         0.0126  2.470588
# 126           0.002400         0.0108  2.400000
# 40            0.002279         0.0139  2.278689
# 127           0.002378         0.0107  2.377778
# 63            0.002107         0.0118  2.107143
# 72            0.002111         0.0114  2.111111
# 17            0.002353         0.0160  2.352941
# 77            0.002396         0.0127  2.396226
# 79            0.002077         0.0108  2.076923
# 89            0.002520         0.0126  2.520000
# 83            0.002373         0.0121  2.372549
# 117           0.002717         0.0125  2.717391
# 80            0.002731         0.0142  2.730769
# 60            0.002246         0.0128  2.245614
# 2             0.002863         0.0229  2.862500
# 65            0.002732         0.0153  2.732143
# 32            0.002625         0.0168  2.625000
# 23            0.002303         0.0152  2.303030
# 56            0.002737         0.0156  2.736842
# 67            0.002436         0.0134  2.436364
# 42            0.002583         0.0155  2.583333
# 6             0.002487         0.0189  2.486842
# 54            0.002828         0.0164  2.827586
# 114           0.002511         0.0118  2.510638
# 48            0.002458         0.0145  2.457627
# 90            0.002520         0.0126  2.520000
# 29            0.002369         0.0154  2.369231
# 4             0.002641         0.0206  2.641026
# 14            0.002232         0.0154  2.231884
# 10            0.002324         0.0165  2.323944
# 3             0.002949         0.0230  2.948718
# 9             0.003194         0.0230  3.194444
# 8             0.003082         0.0225  3.082192
# 26            0.003258         0.0215  3.257576
# 11            0.003129         0.0219  3.128571
# 49            0.003362         0.0195  3.362069
# 73            0.003463         0.0187  3.462963
# 86            0.002980         0.0152  2.980392

# %%
Tuesday = master_df[master_df['Name'].isin(['Dolphins ','Drew Brees',
                'Alvin Kamara', 'Ezekiel Elliott', 'DeVante Parker', 
                'Julian Edelman', "N'Keal Harry", 'Darren Waller', "Joe Mixon"])]
Wednesday = master_df[master_df['Name'].isin(['Buccaneers ','Ryan Fitzpatrick',
                'Alvin Kamara', 'Mike Davis', 'DeVante Parker', 
                'Julian Edelman', "Robert Woods", 'Darren Waller', "Hunter Henry"])]
Thursday = master_df[master_df['Name'].isin(['Dolphins ','Drew Brees',
                'Alvin Kamara', 'Ezekiel Elliott', 'DeVante Parker', 
                'Julian Edelman', "N'Keal Harry", 'Darren Waller', "Joe Mixon"])]
Friday = master_df[master_df['Name'].isin(['Dolphins ','Drew Brees',
                'Alvin Kamara', 'Ezekiel Elliott', 'DeVante Parker', 
                'Julian Edelman', "N'Keal Harry", 'Darren Waller', "Joe Mixon"])]

# %%
print(Tuesday['Projected Points'].sum(),Tuesday['Salary'].sum())
# Out:
# 139.89999999999998 50000

# %%
print(Wednesday['Projected Points'].sum(),Wednesday['Salary'].sum())
# Out:
# 138.5 50000

# %%
print(Thursday['Projected Points'].sum(),Thursday['Salary'].sum())
# Out:
# 139.89999999999998 50000

# %%
print(Friday['Projected Points'].sum(),Friday['Salary'].sum())
# Out:
# 139.89999999999998 50000
